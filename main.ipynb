# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload
from functions import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### [RQ1]
# #### 1. What’s the operation users repeat more on average within a session? Produce a plot that shows the average number of times users perform each operation (view/removefromchart etc etc).

# %%
avg_user_operation()

# %% [markdown]
# #### 2. How many times, on average, a user views a product before adding it to the cart?

# %%
avg = average_view_before_buy()
print("Average views before adding to cart: %.2f" % avg)

# %% [markdown]
# #### 3. What’s the probability that products added once to the cart are effectively bought?

# %%
p = purchase_probabily()
print("Probability of purchase after adding to cart: {:.2%}".format(p))
# Out:
# Probability of purchase after adding to cart: 66.24%

# %% [markdown]
# #### 4. What’s the average time an item stays in the cart before being removed?
#
# (not answer because there was no "removefromcart" event in the dataset)

# %% [markdown]
# #### 5. How much time passes on average between the first view time and a purchase/addition to cart?

# %%
print("Average time to cart/purchase after view:", avgtime_after_view())
# Out:
# Average time to cart/purchase after view: 2 min 49 sec

# %% [markdown]
# ### [RQ2]

# %%
top_purchase, top10 = most_visited_subcategories("2019-Oct.csv")

plt = top_purchase.plot.bar(title="Top purchased category October 2019")
plt.set_xlabel("Category ID")
plt.set_ylabel("Number of purchases")
# Out:
# Text(0, 0.5, 'Number of purchases')

# %%
top10
# Out:
#                                 Number of purchases
# category_id         product_id
# 2053013552226107603 8600067                       9
#                     8600175                       7
#                     8600140                       3
#                     8600037                       2
#                     8600189                       1
#                     8600043                       1
#                     8600044                       1
#                     8600036                       1
#                     8600214                       1
#                     8600174                       1
# 2053013552259662037 8500140                     141
#                     8500088                     109
#                     8500139                     101
#                     8500131                      91
#                     8500086                      87
#                     8500141                      82
# ...

# %%
top_purchase, top10 = most_visited_subcategories("2019-Nov.csv")

plt = top_purchase.plot.bar(title="Top purchased category Novermber 2019")
plt.set_xlabel("Category ID")
plt.set_ylabel("Number of purchases")
# Out:
# Text(0, 0.5, 'Number of purchases')

# %%
top10
# Out:
#                                 Number of purchases
# category_id         product_id
# 2053013552259662037 8500140                     271
#                     8500139                     193
#                     8500131                     191
#                     8500141                     154
#                     8500187                     148
#                     8500273                     127
#                     8500088                     116
#                     8500247                     111
#                     8500137                     101
#                     8500086                      97
# 2053013552293216471 6200514                     347
#                     6200806                     312
#                     6200315                     256
#                     6201019                     220
#                     6200724                     218
#                     6200547                     190
# ...

# %% [markdown]
# ### [RQ3]

# %% [markdown]
# #### For each category, what’s the brand whose prices are higher on average?
# ##### Write a function that asks the user a category in input and returns a plot indicating the average price of the products sold by the brand.

# %%
avgPrice("electronics.clocks")

# %% [markdown]
# ##### Find, for each category, the brand with the highest average price. Return all the results in ascending order by price.

# %%
listofhigh_average()

# %% [markdown]
# ### [RQ4]

# %% [markdown]
# #### How much does each brand earn per month?
# ##### Write a function that given the name of a brand in input returns, for each month, its profit.Is the average price of products of different brands significantly different?

# %%
#by just comparing these two brand we can find out that there is significant diffrenet in brand avergae price
Totall_Brand_Sales("zte")
Totall_Brand_Sales("apple")

# %% [markdown]
# ##### Using the function you just created, find the top 3 brands that have suffered the biggest losses in earnings between one month and the next, specifing bothe the loss percentage and the 2 months (e.g., brand_1 lost 20% between march and april).

# %%
top3lost()

# %% [markdown]
# ### [RQ5]

# %% [markdown]
# **Context**: Knowing which days of the week or even which hours of the day shoppers are likely to visit your online store and make a purchase may help you improve your strategies.
#
# **Bussiness question. Sub-Task 1**: In what part of the day is your store most visited?

# %%
rq = RQ5()
rq5.visitors_by_part_of_day()
# Out:
# Subtask-1. Visitors by part of the day
#    period  visitors                day_part
# 0       1     55102    night 12 a.m.-6 a.m.
# 1       2     97455  morning 6 a.m.-12 p.m.
# 2       3    100703       day 12 p.m.-6 p.m
# 3       4     30207   evening 6 p.m.-12 a.m

# %% [markdown]
# **Visualisation. Sub-Task 2**: Create a plot that for each day of the week show the hourly average of visitors your store has.

# %%
rq5.plot_average_visitors_by_hours()

# %% [markdown]
# **Summary:** The plot allows to determine the peak website traffic time: from 12 p.m. to 6 p.m. Moreover it is seen that among all days of the week, website attandance on Sunday is the highest one.

# %% [markdown]
# ### [RQ6]

# %% [markdown]
# **Bussiness question. Sub-Task 1**: Find the overall conversion rate of your store

# %%
rq6.store_conversion_report()
# Out:
# Overall store conversion: 0.51%
# Overall store conversion by user: 32.91%

# %% [markdown]
# **Visualisation. Sub-Task 2**: Plot the number of purchases of each category and show the conversion rate of each category in decreasing order.

# %%
rq6.plot_categories_by_conversion_rate()

# %%
rq6.plot_categories_by_num_of_purchases()

# %% [markdown]
# ### [RQ7]

# %%
income_percent = pareto_principle()
print("20% of customers spent {:.2%} of the total income".format(income_percent))
# Out:
# 20% of customers spent 80.99% of the total income
